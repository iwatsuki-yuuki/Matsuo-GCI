# %% [markdown]
# <a href="https://colab.research.google.com/github/iwatsuki-yuuki/Matsuo-GCI/blob/main/GCI%E6%9C%80%E7%B5%82%E8%AA%B2%E9%A1%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GCI最終課題
#
# **本データセットは、IBM HR Analytics Employee Attrition & Performanceを最終課題用に変更を加えたもの。**
#
# https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset
#
# **提案先は大手ITコンサル企業を想定。**

# %% [markdown]
# データセットの内容
# 大手ITコンサル企業であるI社の過去の人事データで、離職したかどうかなどについて記述されている
# 一部カラムについての説明が明らかになっている（「2.カラムの説明」参照）
# 約1500人の従業員についてのcsvファイルが提供されている
#
#
# 1.   大手ITコンサル企業であるI社の過去の人事データで、離職したかどうかなどについて記述されている
# 2.   一部カラムについての説明が明らかになっている
# 3.   約1500人の従業員についてのcsvファイルが提供されている

# %% [markdown]
# **状況設定と出題**

# %% [markdown]
# あなたは、ITコンサルティング会社の新人アソシエイトです。
# 先日会社の営業部が、複数の会社からデータ分析のPoC(★)を受注してきました。
# これらの会社には機械学習に詳しい人材はおらず、長年に渡り蓄積したデータをどのように事業に活かせばよいのかを苦慮しているとのことです。
# 今回のPoCでは、提供されたデータのEDAや機械学習を用いての分析を行います。分析の結果からこれらの会社固有の課題を設定し、これを解決する事業の内容・効果を示します。
# アソシエイトであるあなたは、データ分析と機械学習に基づく事業を提案するプレゼンをしなければなりません。
# 分析と提案次第では、あなたが選んだ会社と正式にコンサルティング契約を結ぶことができ、あなたは、機械学習を用いた事業開発を主導することができるでしょう。

# %% [markdown]
# **要件**

# %% [markdown]
# 1.   技術説明だけに終始せず、事業提案を行っていること
# 2.   一般論のみに基づく事業提案とせず、与えられたデータセットに対する探索的データ分析（EDA）を行うことでA社固有の課題を提示していること
# 3.   事業提案の一部にて機械学習・統計分析モデル構築を適切に利用しモデル名+評価指標名+スコアを報告、さらにモデルから定量的な示唆を得た痕跡を示すこと
# 4.   外部データや論文等を参照して市場分析を行っていること
# 5.   機械学習に関して事前知識をもたないクライアント企業役員でも理解できるよう説明性を持たせてあること
# 6.   数値を羅列するだけに留まらず、データの可視化を行っていること
# 7.   データの一部のみに言及したり、外部情報を元にあらかじめ特定のデータに限って分析するのではなく、提供データ全体を分析した上でクライアントのどんな課題を解決するか意思決定していること
# 8.   分析から事業提案まで、スライドを通して論理性があること

# %% [markdown]
# ##  事業提案の流れ

# %% [markdown]
# **1**.   背景整理
#
#
# >ここでは大雑把にデータや業界、企業の基本情報を理解する
# > *   市場分析
# >
# >　　  企業、業界の基本的な情報や収益の出し方、プレイヤー、一般的な課題などについて調べます
# > *   EDA(データプレパレーション)
# >
# >　　    データの形状やカラム、欠損値、各カラムの基本的な可視化などを行い、企業(データ)の大まかな理解をし、特有の課題発見につなげます
#
#
# **2**.   課題仮説立案
#
# >課題仮説を複数立て、そのうち一つを選択します
#
#
# **3**.   課題仮説検証
#
#
# 　　  ここでは課題仮説にフォーカスして事例や背景を調べ、課題が正しいか、課題の解像度(具体性)を上げていきます
#
#
# > *   市場分析
# >
# >　　  課題仮説に関連した事例やその課題がどのように評価されているか、どう解決されているかを特定します
# > *   EDA(データプレパレーション)
# >
# >　　    課題に関連したカラムに絞り、そのカラムと他のカラムの関連性を詳細に分析します
#
#
# **4**.  打ち手(ソリューション)仮説立案
#
# >仮説検証で解像度(具体性)を上げた仮説を踏まえ、それに対する打ち手を立案する
#
# **5**.  打ち手(ソリューション)仮説検証
#
# >打ち手の有効性とImpactを定量・定性的に評価する

# %% [markdown]
# ## 1.背景整理

# %% [markdown]
# ### 1-1.市場分析

# %% [markdown]
# - 市場規模（コンサルティング業界）
#     - 国内：市場規模約2兆円(2023年)
#       -  成長率は4%
#     - 　海外：市場規模約52兆円(2023年)
#       - 成長率は4.8%
#
# - 市場規模（ITコンサルティング業界）
#     - 国内：市場規模約6800億円(2025年)
#       -  成長率は5.6%
#     - 　海外：市場規模約9.5兆円(2021年)
#       - 成長率は不明
#       - 2028年に1000億ドル（14.7兆円）になると予想されていることから単純計算で現在は12兆円くらいあると予想される
#
# - まとめ
#   - ITコンサルティング業界の方がコンサルティング業界全体よりも成長率が高い（以降コンサルと略記で表記する）
#   - 上の市場規模のデータから日本はITコンサル業界がコンサル業界全体のうちの市場規模の割合がが0.34%、海外が0.18%ほどである
#
#
# - 参考リンク
#   - https://gyokai-search.com/5-kibo.html
#   - https://consulfree.com/blog/consul-market-size/
#   - https://service.xenobrain.jp/forecastresults/market-size/it-consulting
#   - https://www.mind.co.jp/column/028.html
#   - https://fortna.co.jp/consulting_trend/
#   - https://consul.global/post30622/

# %% [markdown]
# - 業界の成長性・近年のトレンド
#     - 生成AI
#     - DX
#     - SDGs
#       - SDGsのを積極的に取り入れている企業は離職率が低いとかあるかも（今回は関係ない）
# - 外部からの影響
#    - アメリカの景気後退による外資系ファームの縮小
#     - アメリカ経済は景気後退に直面し、多くの外資系コンサルファームは事業規模の縮小を余儀なくされている
#     - これにより、プロジェクト数の減少や人員削減が行われ、​特に中小規模のファームでは経営難が深刻化
#     - ​一方で大手ファームは効率化やデジタル領域へのシフトを進め、新たなビジネスモデルの構築に取り組んでいる
#
#    - ロシアのウクライナ侵攻による市況の変化
#     - ウクライナ経済の成長率が2024年の3.6％から2025年は2.7％に減速すると予測
#     - ロシア市場では西側ブランドの再参入が議論されているが、​市場競争は激化し、新たな試練が予想
#     - これらの情勢はコンサルタントがクライアントに提供する戦略やリスク管理のアプローチに重要な影響を与えている
#
# - 参考リンク
#   - https://fortna.co.jp/consulting_trend/

# %% [markdown]
# 【プレイヤー構成】
#
# - 国内の大手ITコンサル企業
#   - トップ企業（売上高は2022年のもの）
#       - NRI
#         - 売上高は6116億円
#         - 金融や製造など幅広い業界でITコンサルティングとシステムソリューションを展開
#         - 高い業績を保持する
#       - アビームコンサルティング
#         - 売上高は991億円
#         - 戦略立案から業務改革、システム導入まであらゆる領域を一気支援
#       - ベイカレントコンサルティング
#         - 売上高は576億円
#         - クライアントごとに専属チームを常駐
#       - フューチャー
#         - 売上高は487億円
#         - 高い技術力
#       - 日立コンサルティング
#         - 日立製作所のグループ傘下のコンサル会社
#         - エネルギーや公共事業に強い
#
# - グローバルの大手ITコンサル企業
#   - トップ企業
#       - アクセンチュア:
#         - 売上高は450億ドル
#         - 世界最大手でクラウドやAIを活用したDX導入をしている
#
#       - デロイト
#         - コンサルティング部門の売り上げが395億ドル
#       - タタコンサルタンシーサービシズ
#         - 売上高は239億ドル
#       - PwC
#         - コンサルティング部門の売り上げが207億ドル
#
#
# - 参考リンク
#   - https://www.kotora.jp/c/51324/
#   - https://www.geekly.co.jp/column/cat-technology/itconsultingcompanys_introduce/#--15
#   - https://www.geekly.co.jp/column/cat-position/itconsulting_company_ranking/
#   - https://www.deloitte.com/global/en/about/recognition/analyst-relations/deloitte-ranked-number-one-consulting-service-provider-worldwide-by-revenue.html
#   - https://managementconsulted.com/revenue-of-top-20-firms/
#   - https://www.kotora.jp/c/76641-2

# %% [markdown]
# - 業界の特徴
#   - ローバルに見ると、ITコンサルティング市場は巨大で寡占的な構造を持っている
#   - 主要プレイヤーは大手総合コンサルティング企業（Big4系のDeloitte, PwC, EY, KPMGやAccenture, IBM等）で、世界中で幅広いサービスを提供し市場シェアを競っている
#   - 自社のDXや組織改革のため専門ファームにプロジェクト委託する例が増えている
# - 参考リンク
#   - https://nagasaki-consulting.com/2024/05/15
#   - https://shimo-tech-trail.com/it-consultant-trend
#
#
#
# ---
#
#
# - 業界の契約体系（大きく分けて二つ）:
#     - 時間、人月ベース契約
#       - コンサルタントの稼働時間や人数に応じて報酬が発生する形態
#       - 日本のコンサル案件ではこれが一般的
#       - コンサルタントの経験や専門性に応じて金額設定がなされる
#     - 固定報酬契約
#       - あらかじめ成果物やスコープを明確に定義し、その達成に対して一定の報酬を支払う契約
#     -
# - 参考リンク
#   - https://consul.global/post3915/
#   - https://support.kodama-system.com/column/it-consulting/it-consulting-cost/
#
#
#
# ---
#
# - クライアントの業種や規模ごとの傾向
#   - コンサルティングサービスを多く利用するのは金融、製造、流通、公共などの業界
#     - 理由はIT投資資金自体が大きいから
#   - 大企業ほど利用が一般的
#
# - 参考リンク
#   - https://www.imagazine.co.jp/idc-report-of-japanese-market-it-service/

# %% [markdown]
# 上記の内容をもとに以下の分析を行う
#
#
# **1.   コンサル業界の離職率について**
# - コンサルティングファームの平均離職率は20%
# - 離職率の増加はコンサルファームの収益安定性や成長性に
# 2.   コンサル業界の満足率

# %% [markdown]
# ### 1-2.EDA(データプレパレーション)

# %% [markdown]
# ここでは簡単なEDA(データプレパレーション)を行い、与えられたデータがどのようなものなのか概要を把握します。

# %% [markdown]
# **データセットの特性について**

# %% [markdown]
# *   銀行の持つ、各顧客のローンに関する情報や顧客がどのような特性を持っているかの情報

# %% [markdown]
# まず、データ読み込みを行います。今回は、コンペのtrain.csvデータだけが与えられていると仮定して分析を行います。

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#最大表示行数の指定
pd.set_option('display.max_columns', 100)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/GCI/last_task/data.csv_')

# %% [markdown]
# データの確認

# %%
# trainデータの確認
print(f"df shape: {df.shape}")
df.head(3)
# Out:
# df shape: (1470, 44)
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
# 1          1  Life Sciences              1               2
# 2          2          Other              1               4
#
#    EnvironmentSatisfaction  Gender  PerformanceIndex  JobInvolvement  \
# 0                        2  Female                94               3
# 1                        3    Male                61               2
# 2                        4    Male                92               2
#
#    JobLevel                JobRole  JobSatisfaction MaritalStatus  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  PerformanceIndex          1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.895238          9.236735     2.910204            1.0
# std       9.151321          8.129551     1.025259            0.0
# min      18.000000          1.000000     1.000000            1.0
# 25%      30.000000          2.000000     2.000000            1.0
# 50%      36.000000          7.000000     3.000000            1.0
# 75%      43.000000         14.000000     4.000000            1.0
# max      60.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  PerformanceIndex  \
# count     1470.000000              1470.000000       1470.000000
# mean      1022.185034                 2.721769         65.891156
# std        602.769132                 1.093082         20.329428
# min          1.000000                 1.000000         30.000000
# ...

# %% [markdown]
# 欠損値の確認

# %%
total = df.isnull().sum().sort_values(ascending = False)
percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
missing_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                          Total  Percent
# Age                          0      0.0
# Attrition                    0      0.0
# BusinessTravel               0      0.0
# Department                   0      0.0
# DistanceFromHome             0      0.0
# Education                    0      0.0
# EducationField               0      0.0
# EmployeeCount                0      0.0
# EmployeeNumber               0      0.0
# EnvironmentSatisfaction      0      0.0
# Gender                       0      0.0
# PerformanceIndex             0      0.0
# JobInvolvement               0      0.0
# JobLevel                     0      0.0
# JobRole                      0      0.0
# JobSatisfaction              0      0.0
# MaritalStatus                0      0.0
# MonthlyAchievement           0      0.0
# NumCompaniesWorked           0      0.0
# Over18                       0      0.0

# %% [markdown]
# カラムの確認

# %%
# object型のカラムの確認（9個）
df.select_dtypes(include=object)
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 HowToEmploy
# ...

# %%
# 数値型のカラムの確認
df.select_dtypes(exclude=object)
# Out:
#       Age  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0      41                 1          2              1               1
# 1      49                 8          1              1               2
# 2      37                 2          2              1               4
# 3      33                 3          4              1               5
# 4      27                 2          1              1               7
# ...   ...               ...        ...            ...             ...
# 1465   36                23          2              1            2061
# 1466   39                 6          1              1            2062
# 1467   27                 4          3              1            2064
# 1468   49                 2          3              1            2065
# 1469   34                 8          3              1            2068
#
#       EnvironmentSatisfaction  PerformanceIndex  JobInvolvement  JobLevel  \
# ...

# %%
df.select_dtypes(exclude=object).columns
# Out:
# Index(['Age', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'PerformanceIndex',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyAchievement',
#        'NumCompaniesWorked', 'OverTime', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Incentive', 'RemoteWork', 'MonthlyIncome',
#        'StressRating', 'WelfareBenefits', 'InHouseFacility',
#        'ExternalFacility', 'ExtendedLeave', 'FlexibleWork',
#        'StressSelfReported', 'Year'],
#       dtype='object')

# %% [markdown]
# 気になる数値データを可視化する

# %%
import math
import seaborn as sns

num_cols = [
    'Age','DistanceFromHome','Education',
    'EnvironmentSatisfaction','PerformanceIndex','JobInvolvement','JobLevel',
    'JobSatisfaction','MonthlyAchievement','NumCompaniesWorked','OverTime',
    'PerformanceRating','RelationshipSatisfaction','StandardHours',
    'StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear',
    'WorkLifeBalance','YearsAtCompany','YearsInCurrentRole',
    'YearsSinceLastPromotion','YearsWithCurrManager','Incentive',
    'RemoteWork','MonthlyIncome','StressRating','WelfareBenefits',
    'InHouseFacility','ExternalFacility','ExtendedLeave','FlexibleWork',
    'StressSelfReported','Year'
]

cols_per_row = 5
n_rows        = math.ceil(len(num_cols) / cols_per_row)

fig, axes = plt.subplots(
    n_rows, cols_per_row,
    figsize=(cols_per_row * 4, n_rows * 3),
    constrained_layout=True
)
axes = axes.flatten()

for i, col in enumerate(num_cols):

    sns.histplot(data=df, x=col, ax=axes[i], kde=True, color='steelblue')
    axes[i].set_title(col, fontsize=10)


for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.show()

# %%
 # 平均年収を求める
 df['MonthlyIncome'].sum()/df['MonthlyIncome'].count()*12*147
# Out:
# np.float64(12210861.6)

# %%
#平均年収は1229万円

# %% [markdown]
# object型を扱いやすいように数値にする

# %%
# AttritionのYesを1に、Noを2に変換する
df['Attrition'] = df['Attrition'].replace({'Yes': 1, 'No': 0}).astype('int8')
# Out:
# /tmp/ipython-input-384-1155047397.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Attrition'] = df['Attrition'].replace({'Yes': 1, 'No': 0}).astype('int8')

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# 0    1232
# 1     238
# Name: count, dtype: int64

# %%
# BusineesTravelをラベルエンコーディング
bt_map = {
    'Non-Travel': 0,
    'Travel_Rarely': 1,
    'Travel_Frequently': 2
}
df['BusinessTravel'] = df['BusinessTravel'].map(bt_map).astype('int8')

# %%
df['BusinessTravel'].value_counts()
# Out:
# BusinessTravel
# 1    1043
# 2     277
# 0     150
# Name: count, dtype: int64

# %%
# インセンティブ受給率（0 でない人の割合）を計算
rd_rate = (df.loc[df['Department'] == 'Research & Development', 'Incentive'] > 0).mean()

print(f"Research & Development 部門のインセンティブ受給率: {rd_rate:.2%}")
# Out:
# Research & Development 部門のインセンティブ受給率: 44.02%

# %%
# インセンティブ受給率（0 でない人の割合）を計算
rd_rate = (df.loc[df['Department'] == 'Sales', 'Incentive'] > 0).mean()

print(f"Sales 部門のインセンティブ受給率: {rd_rate:.2%}")
# Out:
# Sales 部門のインセンティブ受給率: 42.83%

# %%
# インセンティブ受給率（0 でない人の割合）を計算
rd_rate = (df.loc[df['Department'] == 'Human Resources', 'Incentive'] > 0).mean()

print(f"Human Resources 部門のインセンティブ受給率: {rd_rate:.2%}")
# Out:
# Human Resources 部門のインセンティブ受給率: 28.57%

# %% [markdown]
# | **部門** | **インセンティブ受給率** |
# | --- | --- |
# | **Research & Development** | 44.02 % |
# | **Sales** | 42.83 % |
# | **Human Resources** | 28.57 % |

# %%
# Departmentの数を確認してラベルエンコーディング
df['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
dept_map = {
    'Sales': 0,
    'Research & Development': 1,
    'Human Resources': 2
}
df['Department'] = df['Department'].map(dept_map).astype('int8')

# %%
# EducationFieldの数を確認してラベルエンコーディング
df['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       605
# Medical             466
# Marketing           156
# Technical Degree    129
# Other                86
# Human Resources      28
# Name: count, dtype: int64

# %%
edu_map = {
    'Life Sciences'     : 0,
    'Medical'           : 1,
    'Marketing'         : 2,
    'Technical Degree'  : 3,
    'Other'             : 4,
    'Human Resources'   : 5
}

df['EducationField'] = df['EducationField'].map(edu_map).astype('int8')

# %%
# Genderの数を確認してラベルエンコーディング
df['Gender'].value_counts()
# Out:
# Gender
# Male      886
# Female    584
# Name: count, dtype: int64

# %%
gender_map = {'Male': 0, 'Female': 1}
df['Gender'] = df['Gender'].map(gender_map).astype('int8')

# %%
# JobRoleの数を確認してラベルエンコーディング
df['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              328
# Research Scientist           291
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    133
# Manager                      101
# Sales Representative          82
# Research Director             79
# Human Resources               52
# Name: count, dtype: int64

# %%
job_map = {
    'Sales Executive'          : 0,
    'Research Scientist'       : 1,
    'Laboratory Technician'    : 2,
    'Manufacturing Director'   : 3,
    'Healthcare Representative': 4,
    'Manager'                  : 5,
    'Sales Representative'     : 6,
    'Research Director'        : 7,
    'Human Resources'          : 8
}

df['JobRole'] = df['JobRole'].map(job_map).astype('int8')

# %%
# MaritalStatus（結婚してるかどうか）の数を確認してラベルエンコーディング
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     673
# Single      468
# Divorced    329
# Name: count, dtype: int64

# %%
MartitalStatus_map = {
    'Single' : 0,
    'Married': 1,
    'Divorced': 2
}

df['MaritalStatus'] = df['MaritalStatus'].map(MartitalStatus_map).astype('int8')

# %%
# この列は全てYで18歳以上しかいなかったから削除する
df['Over18'].value_counts()
df = df.drop(columns=['Over18'])

# %%
# HowToEmployの数を確認してラベルエンコーディング
df['HowToEmploy'].value_counts()
# Out:
# HowToEmploy
# intern                      846
# agent_A                     166
# agent_B                     151
# direct_recruiting           131
# agent_C                     108
# New_graduate_recruitment     68
# Name: count, dtype: int64

# %%
how_map = {
    'intern'                   : 0,
    'agent_A'                  : 1,
    'agent_B'                  : 2,
    'direct_recruiting'        : 3,
    'agent_C'                  : 4,
    'New_graduate_recruitment' : 5
}

df['HowToEmploy'] = df['HowToEmploy'].map(how_map).astype('int8')

# %%
#df = df.drop(columns=['Dept_tmp'])

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   41          1               1           0                 1          2
# 1   49          0               2           1                 8          1
# 2   37          1               1           1                 2          2
# 3   33          0               2           1                 3          4
# 4   27          0               1           1                 2          1
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0               0              1               1                        2
# 1               0              1               2                        3
# 2               4              1               4                        4
# 3               0              1               5                        4
# 4               1              1               7                        1
#
#    Gender  PerformanceIndex  JobInvolvement  JobLevel  JobRole  \
# ...

# %% [markdown]
# 相関係数を確認

# %%
corr=df.corr()
sns.heatmap(corr, square=True, annot=False)
# Out:
# <Axes: >

# %% [markdown]
# 相関の高い順番に並べる

# %%
corr['Attrition'].sort_values(ascending=False)
# Out:
# Attrition                   1.000000
# StressRating                0.184437
# BusinessTravel              0.116077
# DistanceFromHome            0.074684
# NumCompaniesWorked          0.058003
# EducationField              0.056931
# StressSelfReported          0.039347
# OverTime                    0.037973
# HowToEmploy                 0.032751
# Year                        0.011080
# EmployeeNumber              0.000656
# MonthlyAchievement          0.000276
# Gender                     -0.009633
# PerformanceIndex           -0.014094
# PerformanceRating          -0.029690
# JobRole                    -0.035703
# InHouseFacility            -0.041373
# RelationshipSatisfaction   -0.041885
# Education                  -0.044377
# YearsSinceLastPromotion    -0.051023
# ExternalFacility           -0.052470
# WorkLifeBalance            -0.055361
# Department                 -0.055970
# TrainingTimesLastYear      -0.064821
# EnvironmentSatisfaction    -0.079062
# ...

# %% [markdown]
# ## 2.課題仮説立案

# %% [markdown]
# 課題仮説として以下のようなものが考えられる
#
#
# *   離職率が高い
# *   収入が低い
# *   満足度が低い（ストレスが大きい、や福利厚生に対する評価が低い）
#
# 最近は離職率を下げる動き(福利厚生を厚くするなど)が行われている
# (https://www.movin.co.jp/column/column8.html)
#
#
#
# 大手コンサルティングファームでは豊富なリソースと研修制度が充実しているため、社員の定着率が高い傾向にある
#
# (https://fortna.co.jp/do-consultants-have-high-turnover/)

# %% [markdown]
# データの内容をもとに以下の分析を行う
#
#
# **1. コンサル業界の離職率について**
# - 一般企業の平均離職率は14.2%
# - コンサルティングファームの平均離職率は20%
# (https://www.movin.co.jp/column/column8.html)
# - ITコンサルは専門性が高く他のコンサルよりも離職率が低い
# - 以下の記事より 1 名の退職コストは年収の 0.5〜2 倍(https://www.shrm.org/content/dam/en/shrm/shrm-labs/documents/222395-SHRMLabs-_-TechStars-Report-TechnologiesRetention_R3-2.pdf)
# - コンサル業界の平均年収 800 万円級では、1 人当たり 400 万〜1,600 万円が消える計算
# - アクセンチュアの「Project PRIDE」導入後も離職増に伴い給与水準を押し上げ、利益率を圧迫（ヘッドハンティングコストの増加）
# (https://www.accelo.com/post/why-high-talent-turnover-greatest-threat-consulting-firm)
# - Gallup メタ分析によれば、離職率が低い企業は高い企業に比べ収益性が平均 18 %高い
# (https://www.gallup.com/workplace/236927/employee-engagement-drives-growth.aspx)
# - 高離職は「顧客との関係・知識が断絶し、最悪プロジェクト失注」(https://www.accelo.com/post/why-high-talent-turnover-greatest-threat-consulting-firm)
# - 	NRI の離職率 3 %前後は「社内にノウハウが蓄積し競合優位を保つ」好例として転職メディアが紹介(https://tenshoku-base.com/nomura-research-institute-other-company-comparison/)
# - 日系コンサル会社は離職率が全体的に低い
#
# | **企業名** | **平均離職率（直近5年間）** |
# | --- | --- |
# | **野村総合研究所（NRI）** | 約**3%**（自己都合離職率） |
# | **アビームコンサルティング** | 約**7～8%** |
# | **ベイカレントコンサルティング** | 約**8%前後** |
# | **フューチャー株式会社** | 推定**15%程度** (非公表) |
# | **日立コンサルティング** | 約**7.6%** |
#
#
# https://tenshoku-base.com/nomura-research-institute-other-company-comparison/
# https://talentsquare.co.jp/career/abeam-consulting-review/
# https://doda.jp/DodaFront/View/CompanyJobs/j_id__10006765812/
# https://talentsquare.co.jp/career/baycurrent-review/
# https://tenshoku-base.com/baycurrent-consulting-reputation/
# https://syukatsu-kaigi.jp/companies/122944/post_items/11/word_mouths?page=3
# https://doda.jp/DodaFront/View/CompanyJobs/j_id__10094080713/
#
# **2. コンサル業界の収益状況**
#
# - 最初の市場分析でも述べたように優秀な人材にはそれに応じた高い給与が支払われる
# - PerformanceIndex：労働生産性、PerformanceRating：人事評定が高い人の離職は大きく収益に関わると思われる

# %% [markdown]
# ## 3.課題仮説検証

# %% [markdown]
# ### 3-1.市場分析

# %% [markdown]
# 上記の分析を踏まえて
#
#
# 1. 離職率が大きく会社の収益に影響していること
# 2. コンサル業界が定着率増加の動きにあること（離職率はコンサル企業に共通する課題）
# 3. 収益モデルとして優秀な人材の流出が大きく会社の損失に関わるということ
#
# この3つが浮かび上がり、離職率に着目して分析を行う

# %% [markdown]
# ### 3-2.EDA

# %% [markdown]
# Attritionに関するカラムが存在するためそのカラムに着目して検証する

# %% [markdown]
# 離職率を求める

# %%
df['Attrition'].mean()
# Out:
# np.float64(0.1619047619047619)

# %% [markdown]
# 離職率は0.16%

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# 0    1232
# 1     238
# Name: count, dtype: int64

# %% [markdown]
# 相関を求めた中で特に高かったStressRatingとBusinessTravelでデータを調べる

# %%
print('mean:',df.groupby(["Attrition"])["StressRating"].mean())
print('median:',df.groupby(["Attrition"])["StressRating"].median())
df.groupby(["Attrition"])["StressRating"].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# mean: Attrition
# 0    2.427760
# 1    2.869748
# Name: StressRating, dtype: float64
# median: Attrition
# 0    2.0
# 1    3.0
# Name: StressRating, dtype: float64
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: StressRating, dtype: object

# %%
sns.countplot(x="Attrition", hue="StressRating",data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
print('mean:',df.groupby(["Attrition"])["BusinessTravel"].mean())
print('median:',df.groupby(["Attrition"])["BusinessTravel"].median())
df.groupby(["Attrition"])["BusinessTravel"].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# mean: Attrition
# 0    1.059253
# 1    1.226891
# Name: BusinessTravel, dtype: float64
# median: Attrition
# 0    1.0
# 1    1.0
# Name: BusinessTravel, dtype: float64
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: BusinessTravel, dtype: object

# %% [markdown]
# このカラムに関してはカウントプロットの方が可視化に適当そうです。

# %%
sns.countplot(x="Attrition", hue="BusinessTravel",data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %% [markdown]
# lightGBMでAttritionを目的とした予測モデルを作ることによって重要度分析を行う

# %% [markdown]
# エンコーディング処理

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
col=df.select_dtypes(include="object")
col=list(col.columns)

# LabelEncoderで変換
le = LabelEncoder()

for i in col:
  df[i]=le.fit_transform(df[i])
df.head(5)
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   41          1               1           0                 1          2
# 1   49          0               2           1                 8          1
# 2   37          1               1           1                 2          2
# 3   33          0               2           1                 3          4
# 4   27          0               1           1                 2          1
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0               0              1               1                        2
# 1               0              1               2                        3
# 2               4              1               4                        4
# 3               0              1               5                        4
# 4               1              1               7                        1
#
#    Gender  PerformanceIndex  JobInvolvement  JobLevel  JobRole  \
# ...

# %%
from sklearn.model_selection import train_test_split
import lightgbm as lgb

# %%
X = df.drop('Attrition',axis=1)
y = df['Attrition'] # 目的変数
# トレーニングデータ,テストデータの分割
X_train, X_valid, y_train, y_valid = train_test_split(X, y,test_size=0.2, random_state=0)

# %% [markdown]
# 今回は不均衡データであることから、評価指標にはAUCを用いることにします。適切な評価指標を選ぶことは最終課題でも重要です。

# %%
# 学習に使用するデータを設定
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train)

# パラメータ
params = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': {'auc'},
         'num_leaves': 20,
        'max_depth':5,
        'min_data_in_leaf': 3,
        'num_iteration': 100,
        'learning_rate':0.03,
        'num_boost_round':100,
         'early_stopping_rounds':20,
}

# モデルの学習
model = lgb.train(params,
                  train_set=lgb_train,
                  valid_sets=lgb_eval,
                  )

# テストデータの予測
y_pred = model.predict(X_valid)
# Out:
# [LightGBM] [Info] Number of positive: 184, number of negative: 992
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000433 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1376
# [LightGBM] [Info] Number of data points in the train set: 1176, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.156463 -> initscore=-1.684787
# [LightGBM] [Info] Start training from score -1.684787
# Training until validation scores don't improve for 20 rounds
# Did not meet early stopping. Best iteration is:
# [87]	valid_0's auc: 0.831559
# /usr/local/lib/python3.11/dist-packages/lightgbm/engine.py:204: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# ...

# %%
from sklearn.metrics import roc_curve, auc

y_true  = y_valid.values
y_score = y_pred

fpr, tpr, _ = roc_curve(y_true, y_score)
roc_auc     = auc(fpr, tpr)

plt.figure(figsize=(6, 6))

plt.plot([0, 1], [0, 1], linestyle='--', color='grey', label='ランダム (AUC=0.5)')

plt.fill_between(fpr, tpr, alpha=0.25, color='royalblue')

plt.plot(fpr, tpr, color='royalblue', linewidth=2,
         label=f'ROC 曲線 (AUC = {roc_auc:.3f})')

plt.title('ROC 曲線と AUC (離職予測モデル)', fontsize=14)
plt.xlabel('偽陽性率 (FPR)', fontsize=12)
plt.ylabel('真陽性率 (TPR)', fontsize=12)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
feature_cols = X_train.columns.tolist()

# %%
feature_cols
# Out:
# ['Age',
#  'BusinessTravel',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'PerformanceIndex',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyAchievement',
#  'NumCompaniesWorked',
#  'OverTime',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'HowToEmploy',
#  'Incentive',
#  'RemoteWork',
#  'MonthlyIncome',
#  'StressRating',
#  'WelfareBenefits',
#  'InHouseFacility',
#  'ExternalFacility',
#  'ExtendedLeave',
#  'FlexibleWork',
#  'StressSelfReported',
#  'Year']

# %% [markdown]
# 特徴量の重要度を可視化

# %%
lgb.plot_importance(model, height=0.5, figsize=(30,40))
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# 重要と判断された特徴量に関していくつか検討してみる
# それぞれの特徴量に関して、平均値や中央値、データの分布を確認し、離職かどうかでウィルコクソンの順位和検定を有意水準を5%として検定し、2群の中央値に有意差があるか検討

# %% [markdown]
# Ageに関して検討する

# %%
# 離職した人としてない人の年齢の平均と中央値
# 若い人が辞めがち
print('mean:',df.groupby(["Attrition"])["Age"].mean())
print('median:',df.groupby(["Attrition"])["Age"].median())
# Out:
# mean: Attrition
# 0    37.533279
# 1    33.592437
# Name: Age, dtype: float64
# median: Attrition
# 0    36.0
# 1    32.0
# Name: Age, dtype: float64

# %%
df.groupby('Attrition')['Age'].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object

# %% [markdown]
# ウィルコクソンの順位和検定を有意水準を5%として検定し、2群の中央値に有意差があるか検討
#
# 結果はTrueなので優位差がある

# %%
from scipy import stats
s, pvalue = stats.mannwhitneyu(df[df["Attrition"]==1]["Age"]
                , df[df["Attrition"]==0]["Age"]
                ,alternative='two-sided')
pvalue < 0.05
# Out:
# np.True_

# %% [markdown]
# 次にMonthlyincomeで検討

# %%
print('mean:',df.groupby(["Attrition"])["MonthlyIncome"].mean())
print('median:',df.groupby(["Attrition"])["MonthlyIncome"].median())
df.groupby(["Attrition"])["MonthlyIncome"].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# mean: Attrition
# 0    7012.964286
# 1    6452.714286
# Name: MonthlyIncome, dtype: float64
# median: Attrition
# 0    6956.0
# 1    6299.0
# Name: MonthlyIncome, dtype: float64
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: MonthlyIncome, dtype: object

# %%
print('平均（mean）:')
print(df.groupby('Attrition')['MonthlyIncome'].mean().rename({0: '在籍', 1: '離職'}))
print('\n中央値（median）:')
print(df.groupby('Attrition')['MonthlyIncome'].median().rename({0: '在籍', 1: '離職'}))

plt.figure(figsize=(8, 5))

sns.histplot(
    df[df['Attrition'] == 0]['MonthlyIncome'],
    bins=20,
    color='royalblue',
    alpha=0.5,
    label='在籍者'
)

sns.histplot(
    df[df['Attrition'] == 1]['MonthlyIncome'],
    bins=20,
    color='orangered',
    alpha=0.5,
    label='離職者'
)

plt.title('月次収入分布', fontsize=14)
plt.xlabel('月次収入', fontsize=12)
plt.ylabel('人数', fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 平均（mean）:
# Attrition
# 在籍    7012.964286
# 離職    6452.714286
# Name: MonthlyIncome, dtype: float64
#
# 中央値（median）:
# Attrition
# 在籍    6956.0
# 離職    6299.0
# Name: MonthlyIncome, dtype: float64

# %%
median_income = df['MonthlyIncome'].median()

df['high_income'] = df['MonthlyIncome'] >= median_income

rate_by_income = (
    df.groupby('high_income')['Attrition']
      .mean()
      .rename(index={False: '低収入', True: '高収入'})
      .apply(lambda r: f'{r:.2%}')
)

print('月次収入（中央値基準）別の離職率')
print(rate_by_income)
# Out:
# 月次収入（中央値基準）別の離職率
# high_income
# 低収入    20.14%
# 高収入    12.24%
# Name: Attrition, dtype: object

# %%
from scipy import stats
s, pvalue = stats.mannwhitneyu(df[df["Attrition"]==1]["MonthlyIncome"]
                , df[df["Attrition"]==0]["MonthlyIncome"]
                ,alternative='two-sided')
pvalue < 0.05
# Out:
# np.True_

# %% [markdown]
# 以上より年齢と月の収入額が離職率に影響していることがわかった。

# %% [markdown]
# 次にMonthlyAchievement、PerformanceIndex、PerformanceRatingについて検討
# （MonthlyAchievementは3つ目に重要な特徴量であり、他二つと加えてその人の優秀さを示す指標にもなると考えた）

# %%
print('mean:',df.groupby(["Attrition"])["MonthlyAchievement"].mean())
print('median:',df.groupby(["Attrition"])["MonthlyAchievement"].median())
df.groupby(["Attrition"])["MonthlyAchievement"].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# mean: Attrition
# 0    14312.240260
# 1    14317.571429
# Name: MonthlyAchievement, dtype: float64
# median: Attrition
# 0    14263.0
# 1    14174.0
# Name: MonthlyAchievement, dtype: float64
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: MonthlyAchievement, dtype: object

# %%
s, pvalue = stats.mannwhitneyu(df[df["Attrition"]==1]["MonthlyAchievement"]
                , df[df["Attrition"]==0]["MonthlyAchievement"]
                ,alternative='two-sided')
pvalue < 0.05
# Out:
# np.False_

# %%
print('mean:',df.groupby(["Attrition"])["PerformanceIndex"].mean())
print('median:',df.groupby(["Attrition"])["PerformanceIndex"].median())
df.groupby(["Attrition"])["PerformanceIndex"].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# mean: Attrition
# 0    66.017045
# 1    65.239496
# Name: PerformanceIndex, dtype: float64
# median: Attrition
# 0    66.0
# 1    64.5
# Name: PerformanceIndex, dtype: float64
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: PerformanceIndex, dtype: object

# %%
s, pvalue = stats.mannwhitneyu(df[df["Attrition"]==1]["PerformanceIndex"]
                , df[df["Attrition"]==0]["PerformanceIndex"]
                ,alternative='two-sided')
pvalue < 0.05
# Out:
# np.False_

# %%
print('mean:',df.groupby(["Attrition"])["PerformanceRating"].mean())
print('median:',df.groupby(["Attrition"])["PerformanceRating"].median())
df.groupby(["Attrition"])["PerformanceRating"].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# mean: Attrition
# 0    2.546266
# 1    2.466387
# Name: PerformanceRating, dtype: float64
# median: Attrition
# 0    3.0
# 1    2.0
# Name: PerformanceRating, dtype: float64
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: PerformanceRating, dtype: object

# %%
s, pvalue = stats.mannwhitneyu(df[df["Attrition"]==1]["PerformanceRating"]
                , df[df["Attrition"]==0]["PerformanceRating"]
                ,alternative='two-sided')
pvalue < 0.05
# Out:
# np.False_

# %% [markdown]
# また相関が高かったもの(StressRating、BusinessTravel)についても再度調べる

# %%
print('mean:',df.groupby(["Attrition"])["StressRating"].mean())
print('median:',df.groupby(["Attrition"])["StressRating"].median())
df.groupby(["Attrition"])["StressRating"].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# mean: Attrition
# 0    2.427760
# 1    2.869748
# Name: StressRating, dtype: float64
# median: Attrition
# 0    2.0
# 1    3.0
# Name: StressRating, dtype: float64
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: StressRating, dtype: object

# %%
s, pvalue = stats.mannwhitneyu(df[df["Attrition"]==1]["StressRating"]
                , df[df["Attrition"]==0]["StressRating"]
                ,alternative='two-sided')
pvalue < 0.05
# Out:
# np.True_

# %%
print('mean:',df.groupby(["Attrition"])["BusinessTravel"].mean())
print('median:',df.groupby(["Attrition"])["BusinessTravel"].median())
df.groupby(["Attrition"])["BusinessTravel"].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# mean: Attrition
# 0    1.059253
# 1    1.226891
# Name: BusinessTravel, dtype: float64
# median: Attrition
# 0    1.0
# 1    1.0
# Name: BusinessTravel, dtype: float64
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: BusinessTravel, dtype: object

# %%
s, pvalue = stats.mannwhitneyu(df[df["Attrition"]==1]["BusinessTravel"]
                , df[df["Attrition"]==0]["BusinessTravel"]
                ,alternative='two-sided')
pvalue < 0.05
# Out:
# np.True_

# %% [markdown]
# この検定よりMonthlyAchievement、PerformanceIndex、PerformanceRatingは離職率の原因になっていないことがわかった。優秀な人材の離職率のみではなく全体の離職率を予測する方針で進めたいと思う。

# %% [markdown]
# ここまでのデータ分析をまとめると以下の通り。
#
# | **変数** | **在籍者 平均‐中央値** | **離職者 平均‐中央値** | **p 値** | **解釈** |
# | --- | --- | --- | --- | --- |
# | Age | 37.5 − 36.0 | **33.6 − 32.0** | **< 0.05** | 若手ほど辞めやすい |
# | MonthlyIncome | 7,013 − 6,956 | **6,452 − 6,299** | **< 0.05** | 低収入層で離職↑ |
# | **StressRating** | 2.43 − 2.0 | **2.87 − 3.0** | **< 0.05** | 高ストレスで離職↑ |
# | **BusinessTravel**| 1.70 − 1.0 | **1.23 − 1.0** | **< 0.05** | 出張頻度が高いほど離職↑ |
# | MonthlyAchievement / Performance 系 | 差なし | > 0.05 | 成果指標は離職に直結せず |  |

# %% [markdown]
# 今回はEDAの手段としてLightGBMを用いた

# %% [markdown]
# 収入を考えるにあたってインセンティブも重要な特徴量であり給与に直結する点から追加で分析する

# %%
# インセンティブをもらっている人の割合
vc = df['Incentive'].value_counts(normalize=True)  # ← True で割合
print(vc.rename(lambda x: f'額={x}').apply(lambda r: f'{r:.2%}'))
# Out:
# Incentive
# 額=0       57.01%
# 額=3919     0.20%
# 額=1905     0.14%
# 額=2924     0.14%
# 額=3852     0.14%
#            ...
# 額=1909     0.07%
# 額=2654     0.07%
# 額=1581     0.07%
# 額=2101     0.07%
# 額=3403     0.07%
# Name: proportion, Length: 587, dtype: object

# %% [markdown]
# | **対象** | **平均月収** | **平均インセンティブ** |
# | --- | --- | --- |
# | **ギャップ層 357 名** | 105万円 | 7万円 |
# | **全社員 1,470 名** | 102万円 | 17万円 |

# %% [markdown]
# これは一般的なインセンティブ受給率を元のIBMのデータセットから0.57%と求めた。
#
#
# それぞれの部署ごとの受給率は以下の表のとおり
#
#
# | **部門** | **総人数** | **インセンティブ受給率（部門内）** | **受給者数（概算）** |
# | --- | --- | --- | --- |
# | Research & Development | 961 | 63 % | 607 名 |
# | Sales | 446 | 50 % | 223 名 |
# | Human Resources | 63 | 19 % | 12 名 |
# | **合計** | **1470** | — | **842 名** |

# %%
print('mean:',df.groupby(["Attrition"])["Incentive"].mean())
print('median:',df.groupby(["Attrition"])["Incentive"].median())
df.groupby(["Attrition"])["Incentive"].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# mean: Attrition
# 0    1276.359578
# 1     451.890756
# Name: Incentive, dtype: float64
# median: Attrition
# 0    0.0
# 1    0.0
# Name: Incentive, dtype: float64
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: Incentive, dtype: object

# %%
print('平均（mean）:')
print(df.groupby('Attrition')['Incentive'].mean().rename({0: '在籍', 1: '離職'}))
print('\n中央値（median）:')
print(df.groupby('Attrition')['Incentive'].median().rename({0: '在籍', 1: '離職'}))

plt.figure(figsize=(8, 5))

sns.histplot(
    df[df['Attrition'] == 0]['Incentive'],
    bins=20,
    color='royalblue',
    alpha=0.5,
    label='在籍者'
)

sns.histplot(
    df[df['Attrition'] == 1]['Incentive'],
    bins=20,
    color='orangered',
    alpha=0.5,
    label='離職者'
)

plt.title('インセンティブ分布', fontsize=14)
plt.xlabel('インセンティブ額', fontsize=12)
plt.ylabel('人数', fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 平均（mean）:
# Attrition
# 在籍    1276.359578
# 離職     451.890756
# Name: Incentive, dtype: float64
#
# 中央値（median）:
# Attrition
# 在籍    0.0
# 離職    0.0
# Name: Incentive, dtype: float64

# %%
df['has_incentive'] = df['Incentive'] > 0

rate_by_incentive = (
    df.groupby('has_incentive')['Attrition']
      .mean()
      .rename(index={False: '未受給者', True: '受給者'})
      .apply(lambda r: f'{r:.2%}')
)

print('インセンティブ有無別の離職率')
print(rate_by_incentive)
# Out:
# インセンティブ有無別の離職率
# has_incentive
# 未受給者    22.67%
# 受給者      7.59%
# Name: Attrition, dtype: object

# %%
s, pvalue = stats.mannwhitneyu(df[df["Attrition"]==1]["Incentive"]
                , df[df["Attrition"]==0]["Incentive"]
                ,alternative='two-sided')
pvalue < 0.05
# Out:
# np.True_

# %% [markdown]
# インセンティブも離職率に影響していることがわかった
# 今回のデータセットの元になったIBMのインセンティブ制度はデータセットに含まれる職種ごとに違う制度でありまとめると以下の表のようになっている。(http://sec.gov/files/corpfin/no-action/14a-8/heritageibm122024-14a8inc.pdf)
#
#
# | **Research & Development** | **961** | 研究・開発・実装・特許出願 | **① 年次パフォーマンス・ボーナス（AIP）② 技術／特許アワード（Patent & Achievement Awards）** | ・AIP は全管理職／専門職に付与される基礎変動給。・R&D は特許や製品化貢献度が KPI なので **特許アワードが直接給与に上乗せ**されやすい。・人数が最多＝総インセンティブ予算も最大ボリューム。 |
# | --- | --- | --- | --- | --- |
# | **Sales** | **446** | 契約獲得・売上拡大 | **③ 営業インセンティブ（Sales Incentive Compensation）** | ・四半期クォータ達成率に連動し、達成度 >100% で加速報酬。・可変給比率が最も高く、**「給与＝インセンティブ依存度」が突出**。 |
# | **Human Resources** | **63** | 採用・人材開発・制度運営 | **① 年次パフォーマンス・ボーナス（AIP）④ スポット／マネージャーズ・チョイス賞** | ・売上連動ではないため固定＋AIP が中心。・プロジェクト完遂や制度導入時に**スポット賞（現金 500〜2,000 USD）**が出やすい。 |

# %% [markdown]
# ここで成果は出ているが正しく評価されずインセンティブをもらえていない人に注目することにした（もし正しく評価されていなかったら社内評価システムの導入提案などをできるだろうと考えたから）。またこの場合は給与を上げるのではなくインセンティブを上げる人を増やす（0の人が多いので支給額を上げるよりかはもらえるハードルを下げる方が大切だと思った）。

# %% [markdown]
# **コンサル業界のインセンティブ制度について**
#
#
# 1.   1990年代以降、コンサルティング会社は優秀な人材獲得と定着を図るため、給与体系に変動報酬（インセンティブ）を組み込んできた(https://horizontecubano.law.columbia.edu/news/how-incentive-compensation-drives-organizational-results-consulting-companies)
# 2.   レバテックによるとIT人材の84.8%がボーナスを支給されている(https://levtech.co.jp/research/3523978/)
# 3.  コンサル業界では実力主義でインセンティブの割合も大きい(https://assign-inc.com/media/2023/08/16/consulting-career-income/)
# 4.  様々な業界では83.2%が受給(https://www.morganmckinley.com/jp-ja/infographic)

# %%
# MonthlyAchievementに以下の閾値を設けてそれより高いかを確認する
q_high  = 0.70     # 上位30%を「高い」
q_low   = 0.30     # 下位30%を「低い」

# 閾値を計算
ma_high = df['MonthlyAchievement'].quantile(q_high)
pi_high = df['PerformanceIndex'].quantile(q_high)
pr_low  = df['PerformanceRating'].quantile(q_low)

# フラグ列を付ける
df['is_high_MA']  = df['MonthlyAchievement'] >= ma_high
df['is_high_PI']  = df['PerformanceIndex']   >= pi_high
df['is_low_PR']   = df['PerformanceRating']  <= pr_low

# 条件に合う行(MonthlyAchievement か PerformanceIndex のどちらかが高い行)を取り出す
mask = (df[['is_high_MA','is_high_PI']].any(axis=1)) & df['is_low_PR']
gap_df = df[mask]

print('該当レコード数:', len(gap_df))
display(gap_df[['EmployeeNumber','MonthlyAchievement',
                'PerformanceIndex','PerformanceRating']].head())

pivot = (
    gap_df
    .groupby(['Department','JobLevel'])
    .size()
    .unstack(fill_value=0)
    .sort_index(ascending=False)
)
print(pivot.head())
# Out:
# 該当レコード数: 357
#     EmployeeNumber  MonthlyAchievement  PerformanceIndex  PerformanceRating
# 0                1               19479                94                  1
# 3                5               23159                56                  1
# 9               13               16577                94                  2
# 10              14               16479                84                  2
# 13              18                8758                93                  1
# JobLevel     1   2   3   4  5
# Department
# 2           11   3   1   1  3
# 1           99  75  34  16  9
# 0           15  62  15   9  4

# %% [markdown]
# | **部門** | **ジョブレベル 1** | **ジョブレベル 2** | **ジョブレベル 3** | **ジョブレベル 4** | **ジョブレベル 5** |
# | --- | --- | --- | --- | --- | --- |
# | **人事（Human Resources）** | 11 人 | 3 人 | 1 人 | 1 人 | 3 人 |
# | **営業（Sales）** | 99 人 | 75 人 | 34 人 | 16 人 | 9 人 |
# | **研究開発（Research & Development）** | 15 人 | 62 人 | 15 人 | 9 人 | 4 人 |

# %% [markdown]
# ギャップ対象者の平均年収と中央値年収を求める（利益の計算に必要）

# %%
gap_avg_income = df.loc[mask, 'MonthlyIncome'].mean()
print(f'ギャップ対象者の平均月収：{gap_avg_income:,.2f}ドル')
# Out:
# ギャップ対象者の平均月収：7,125.90 ドル

# %%
gap_median_income = df.loc[mask, 'MonthlyIncome'].median()
print(f'ギャップ対象者の月次収入 **中央値**：{gap_median_income:,.2f}ドル')
# Out:
# ギャップ対象者の月次収入 **中央値**：7,085.00 ドル

# %%
# 後々使うためgap_flag列を作成
df['gap_flag'] = (
        ((df['MonthlyAchievement'] >= ma_high) |   # どちらか高い
         (df['PerformanceIndex']   >= pi_high))
        &
        (df['PerformanceRating']   <= pr_low)      # かつ評価が低い
).astype(int)          # 1=True, 0=False

print('ギャップ対象者数:', df['gap_flag'].sum())
# Out:
# ギャップ対象者数: 357

# %%
! pip install japanize-matplotlib

# %%
import japanize_matplotlib

# %%
import seaborn as sns
rating_palette = {
    1: '#db7093',
    2: '#9370db',
    3: '#00bfff',
    4: '#1e90ff',
}

plt.figure(figsize=(8, 6))

sns.scatterplot(
    data=df,
    x='MonthlyAchievement',
    y='PerformanceIndex',
    hue='PerformanceRating',
    palette=rating_palette,
    alpha=0.6,
    edgecolor='none',
    s=50,
    legend='brief'
)

sns.scatterplot(
    data=gap_df,
    x='MonthlyAchievement',
    y='PerformanceIndex',
    hue='PerformanceRating',
    palette=rating_palette,
    edgecolor='black',
    linewidth=0.5,
    s=80,
    marker='o',
    legend=False
)

plt.axvline(ma_high, color='grey', linestyle='--', linewidth=1)
plt.axhline(pi_high, color='grey', linestyle='--', linewidth=1)

plt.title('評価と成果にギャップがある人\n色：人事評価（低評価ほど暖色 → 高評価ほど寒色）', fontsize=14, pad=12)
plt.xlabel('月次成果', fontsize=12)
plt.ylabel('パフォーマンス指数', fontsize=12)
plt.legend(title='人事評価', title_fontsize=11, fontsize=10, loc='lower right', frameon=True)
plt.tight_layout()
plt.show()

# %%
df['JobLevel'].value_counts()
# Out:
# JobLevel
# 2    536
# 1    536
# 3    220
# 4    108
# 5     70
# Name: count, dtype: int64

# %% [markdown]
# この結果から以上のことがわかった
#
# *   「MonthlyAchievement か PerformanceIndex が上位30％以上 かつ PerformanceRating が下位30％以下」という“高成果なのに評価が低い”ギャップ社員が357名いる(indexは1470であり訳25%の人にギャップがあるという大きな数字)
# *   Research & Developmentでjoblevelが1に99人、Salesでjoblevel2に62人とjoblevelの低い人に特に集まっていた（joblevelが1or2の人が全体の7割を占めているので妥当ではある）

# %% [markdown]
# ギャップのある人たちがどのくらいのお金をもらっているのか調べる

# %%
cols = ['MonthlyIncome', 'Incentive']

gap_mean = gap_df[cols].mean()

all_mean = df[cols].mean()

print('ギャップ層357名の平均')
print(gap_mean.round(2))
print('\n全社員平均')
print(all_mean.round(2))
# Out:
# ギャップ層357名の平均
# MonthlyIncome    7125.90
# Incentive         472.53
# dtype: float64
#
# 全社員平均
# MonthlyIncome    6922.26
# Incentive        1142.87
# dtype: float64

# %% [markdown]
# 給与そのものは平均より少し高いが、インセンティブは半分以下になっている
#
#
# なぜこのようになるのか考察
# 1. **評価バイアス**
#     - パフォーマンス指数・成果は高いのに上司評価が低い → インセンティブ閾値を超えられない。
# 2. **制度設計のミスマッチ**
#     - インセンティブ基準がSalesよりのKPIで、Research & Developmentの若手などの成果が換算されない。

# %% [markdown]
# ## 4.打ち手仮説立案

# %% [markdown]
# 「課題仮説:離職率の高さ」に対する打ち手を列挙していく。
#
# 若手 × 低収入 × 高ストレス × 出張過多の離職率を高めている重要な要因であった。
#
#
# また若手が評価されていない現状にも問題があると判断した。

# %% [markdown]
# - 離職率予測+若者のストレス軽減×出張過多防止
#     - リモートツールの導入によってストレスの軽減と出張過多を防ぐ
#     - 出張の量を均等にする＋全体の主張回数を減らす
#     - リモートによる情報共有不足を解消するシステムも検討？
# - 離職率予測＋ストレス軽減＋収入増やす
#     - 市場分析の時に離職率を減らすための取り組みとして以下のものが見られた
#         1.   給与全体の上昇
#         2.   福利厚生や研修制度の充実
#     - 実際になされている取り組みである
# - 離職率予測＋インセンティブの改善（収入増やす）
#     - 正しく評価される人事制度の導入

# %% [markdown]
# ## 5.打ち手仮説検証1

# %% [markdown]
# **離職率予測モデルで離職確率が高いと予測された従業員でかつギャップのある従業員にインセンティブを支給する**

# %% [markdown]
# 先ほど作ったモデルで予測を行い、離職する確率を出す。

# %%
y_pred_1 = model.predict(X_valid)

# %%
df_1 = X_valid.copy()

# %%
df_1['pred']= y_pred_1
df_1['pred'].hist()
# Out:
# <Axes: >

# %% [markdown]
# このヒストグラムから離職予備軍の閾値を設定する
# 見込み離職率を238/1470=16%から上位20%をハイリスクとすることに決定

# %%
threshold=df_1['pred'].quantile(0.8)
print(threshold)
df_1.loc[df_1['pred'] < threshold, 'pred'] = 0
df_1.loc[df_1['pred'] >= threshold, 'pred'] = 1
# Out:
# 0.18121491820394597

# %%
df_now = df.copy()
df_now['pred_prob_now'] = model.predict(df_now[feature_cols])

df_after = df.copy()
df_after.loc[df_after['gap_flag'] == 1, 'Incentive'] = 1156
df_after['pred_prob_after'] = model.predict(df_after[feature_cols])

# %%
df_cmp = (df_now[['pred_prob_now']]
          .join(df_after['pred_prob_after']))
df_cmp['delta_prob'] = df_cmp['pred_prob_now'] - df_cmp['pred_prob_after']

# %%
exp_leave_before = df_cmp['pred_prob_now'].sum()
exp_leave_after  = df_cmp['pred_prob_after'].sum()
prevented_head   = exp_leave_before - exp_leave_after

mean_before = df_cmp['pred_prob_now'].mean()
mean_after  = df_cmp['pred_prob_after'].mean()
mean_drop   = mean_before - mean_after

print(f'防止できる期待離職者数: {prevented_head:.2f} 名')
print(f'全社員比              : {prevented_head/len(df_cmp):.2%}')
print('――――――――――――――――――――――――――――――')
print(f'平均離職確率 施策前   : {mean_before:.2%}')
print(f'平均離職確率 施策後   : {mean_after:.2%}')
print(f'平均離職確率 低減幅   : {mean_drop:.2%}')
# Out:
# 防止できる期待離職者数: 5.66 名
# 全社員比              : 0.38%
# ――――――――――――――――――――――――――――――
# 平均離職確率 施策前   : 15.29%
# 平均離職確率 施策後   : 14.91%
# 平均離職確率 低減幅   : 0.38%

# %%
thr = df_now['pred_prob_now'].quantile(0.80)
df_now['high_risk'] = (df_now['pred_prob_now'] >= thr).astype(int)

# %%
target = df_now.loc[(df_now['gap_flag'] == 1) & (df_now['high_risk'] == 1)].copy()

print('支給対象人数:', len(target))
# Out:
# 支給対象人数: 85

# %% [markdown]
# https://the21.php.co.jp/detail/7094?p=1
#
#
# 採用コストは平均年収の1.5倍とする(1250*1.5)
#
# 平均年収1250万円のひとが生み出す営業利益(最終的に会社に残る利益)500万円

# %% [markdown]
# 受給対象者は85名
#
#
# この施策によって減る離職確率は0.38%になり優秀な人材の6名の離職を防ぐことができる
#
#
# ギャップ対象者の平均年収は1250万円
#
#
# インセンティブの合計金額は85✖️20=1200万円
#
#
# この人たちが離職しなかった際の会社の実質的な収益は(1250✖️1.5 + 500)✖️6=1.3億円

# %% [markdown]
# ## 6.打ち手仮説検証2

# %% [markdown]
# **離職率予測+若者のストレス軽減×出張過多防止**
#
# 若者(Age<=30)のストレスを一段階下げ、BusinessTravelは若者は全体平均にする

# %%
# 基準データ
df_base = df.copy()
df_base['pred_prob_now'] = model.predict(df_base[feature_cols])

# 若手用
df_young = df.copy()

# 30歳以下は若者扱い
young_mask = df_young['Age'] <= 30

# StressRatingを1下げる
df_young.loc[young_mask, 'StressRating'] = (
    df_young.loc[young_mask, 'StressRating'] - 1
).clip(lower=1)

# BusinessTravelを全社平均に置換
bt_mean = df['BusinessTravel'].mean()
df_young.loc[young_mask, 'BusinessTravel'] = round(bt_mean)

df_young['pred_prob_young'] = model.predict(df_young[feature_cols])

import pandas as pd

cmp = pd.DataFrame({
    'base'  : df_base ['pred_prob_now'],
    'young' : df_young['pred_prob_young']
})
cmp['delta_prob'] = cmp['base'] - cmp['young']

mean_drop = cmp['delta_prob'].mean()
print(f'平均離職確率低減幅 : {mean_drop:.2%}')

prevented = cmp['delta_prob'].sum()
print(f'防止できる期待離職者数  : {prevented:.1f} 名 ({prevented/len(cmp):.2%} 全社員比)')
# Out:
# 平均離職確率低減幅 : 0.69%
# 防止できる期待離職者数  : 10.2 名 (0.69% 全社員比)

# %% [markdown]
# 離職防止者は10人
# 平均年収は1200万円
# この施策によって生じる利益は10✖️(1200*1.5+500)=2.3億円

# %% [markdown]
# インパクトは施策2の方が大きいが、I社が他の企業と比べてかなりインセンティブ受給率が少ないことから現実的な効果、改善性が高いと思い施策1で資料を作ることにする

# %% [markdown]
# **マネタイズ**
#
#
#
#
# *   年間1.3億円
# *   ROIを50%とすると1年目でが上限目安
# *   初期投資が4000万円、コンサル費用が6000万円、運用費が1.6億円の計算
#
#
#
#
#
# 参考URL
# * https://solashi.com/media/system-implementation-roi-improvement-calculation-importance/
#
# * https://www.it-seibishi.or.jp/4138/
